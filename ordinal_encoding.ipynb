# %%
# 1. Import libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder


# 2. Load dataset
df = pd.read_csv("Employee_Performance_EDA_Practice.csv")

# Check original data
print(df.head())
# Out:
#    Employee_ID  Age  Gender Education  Experience Department    City   Salary  \
# 0          101   22    Male  Bachelor           1         HR  Mumbai  25000.0
# 1          102   25  Female    Master           3         IT    Pune  42000.0
# 2          103   30    Male  Bachelor           6      Sales   Delhi  65000.0
# 3          104   28  Female       PhD           5         IT  Mumbai  72000.0
# 4          105   35    Male    Master          10    Finance    Pune      NaN
#
#    Performance_Rating  Working_Hours  Projects  Attendance Promotion Purchased
# 0                   3              8         1        90.0        No        No
# 1                   4              9         3        95.0       Yes       Yes
# 2                   5              9         5        97.0       Yes       Yes
# 3                   5              8         4        96.0       Yes       Yes
# 4                   5             10         7        98.0       Yes       Yes

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(
    categories=[
        ["Bachelor", "Master", "PhD"]
    ]
)

df["Education"] = oe.fit_transform(
    df[["Education"]]
)

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender  Education  Experience Department    City  \
# 0          101   22    Male        0.0           1         HR  Mumbai
# 1          102   25  Female        1.0           3         IT    Pune
# 2          103   30    Male        0.0           6      Sales   Delhi
# 3          104   28  Female        2.0           5         IT  Mumbai
# 4          105   35    Male        1.0          10    Finance    Pune
#
#     Salary  Performance_Rating  Working_Hours  Projects  Attendance Promotion  \
# 0  25000.0                   3              8         1        90.0        No
# 1  42000.0                   4              9         3        95.0       Yes
# 2  65000.0                   5              9         5        97.0       Yes
# 3  72000.0                   5              8         4        96.0       Yes
# 4      NaN                   5             10         7        98.0       Yes
#
#   Purchased
# 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
