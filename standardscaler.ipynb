# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Employee_Performance_Dataset.csv")

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Education  Experience Department    City  Salary  \
# 0            1   22    Male  Bachelor           1         HR  Mumbai   25000
# 1            2   25  Female    Master           3         IT    Pune   42000
# 2            3   30    Male  Bachelor           6      Sales   Delhi   65000
# 3            4   28  Female       PhD           5         IT  Mumbai   72000
# 4            5   35    Male    Master          10    Finance    Pune   90000
#
#    Performance_Rating  Working_Hours  Projects  Attendance Promotion Purchased
# 0                   3              8         1          90        No        No
# 1                   4              9         3          95       Yes       Yes
# 2                   5              9         5          97       Yes       Yes
# 3                   5              8         4          96       Yes       Yes
# 4                   5             10         7          98       Yes       Yes

# %%
# single scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
df[["Salary"]]=ss.fit_transform(df[["Salary"]])

# %%
df.head()
# Out:
#    Employee_ID       Age  Gender Education  Experience Department    City  \
# 0            1 -1.376854    Male  Bachelor   -1.191203         HR  Mumbai
# 1            2 -0.894687  Female    Master   -0.800645         IT    Pune
# 2            3 -0.091076    Male  Bachelor   -0.214807      Sales   Delhi
# 3            4 -0.412520  Female       PhD   -0.410086         IT  Mumbai
# 4            5  0.712535    Male    Master    0.566310    Finance    Pune
#
#      Salary  Performance_Rating  Working_Hours  Projects  Attendance  \
# 0 -1.296494                   3              8         1          90
# 1 -0.807070                   4              9         3          95
# 2 -0.144908                   5              9         5          97
# 3  0.056620                   5              8         4          96
# 4  0.574834                   5             10         7          98
#
#   Promotion Purchased
# 0        No        No
# 1       Yes       Yes
# 2       Yes       Yes
# 3       Yes       Yes
# 4       Yes       Yes

# %%
#  multiple scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
numeric_columns=["Age","Experience","Performance_Rating","Working_Hours"]

# %%
df[numeric_columns]=scaler.fit_transform(df[numeric_columns])

# %%
df.head()
# Out:
#    Employee_ID       Age  Gender Education  Experience Department    City  \
# 0            1 -1.376854    Male  Bachelor   -1.191203         HR  Mumbai
# 1            2 -0.894687  Female    Master   -0.800645         IT    Pune
# 2            3 -0.091076    Male  Bachelor   -0.214807      Sales   Delhi
# 3            4 -0.412520  Female       PhD   -0.410086         IT  Mumbai
# 4            5  0.712535    Male    Master    0.566310    Finance    Pune
#
#      Salary  Performance_Rating  Working_Hours  Projects  Attendance  \
# 0 -1.296494                   3              8         1          90
# 1 -0.807070                   4              9         3          95
# 2 -0.144908                   5              9         5          97
# 3  0.056620                   5              8         4          96
# 4  0.574834                   5             10         7          98
#
#   Promotion Purchased
# 0        No        No
# 1       Yes       Yes
# 2       Yes       Yes
# 3       Yes       Yes
# 4       Yes       Yes
