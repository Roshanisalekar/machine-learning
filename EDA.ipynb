# %%
import pandas as pd

data = {
    "Age":[18,22,25,None,30,45,50,22],
    "Salary":[20000,30000,45000,50000,None,90000,120000,30000],
    "Experience":[1,2,3,4,5,10,15,2],
    "Gender":["Male","Female","Female","Male","Male","Female","Male","Female"],
    "Department":["HR","IT","IT","Sales","HR","IT","Sales","IT"],
    "Purchased":["Yes","No","Yes","Yes","No","Yes","No","No"]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Age    Salary  Experience  Gender Department Purchased
# 0  18.0   20000.0           1    Male         HR       Yes
# 1  22.0   30000.0           2  Female         IT        No
# 2  25.0   45000.0           3  Female         IT       Yes
# 3   NaN   50000.0           4    Male      Sales       Yes
# 4  30.0       NaN           5    Male         HR        No
# 5  45.0   90000.0          10  Female         IT       Yes
# 6  50.0  120000.0          15    Male      Sales        No
# 7  22.0   30000.0           2  Female         IT        No

# %%
df.head()
# Out:
#     Age   Salary  Experience  Gender Department Purchased
# 0  18.0  20000.0           1    Male         HR       Yes
# 1  22.0  30000.0           2  Female         IT        No
# 2  25.0  45000.0           3  Female         IT       Yes
# 3   NaN  50000.0           4    Male      Sales       Yes
# 4  30.0      NaN           5    Male         HR        No

# %%
df.tail()
# Out:
#     Age    Salary  Experience  Gender Department Purchased
# 3   NaN   50000.0           4    Male      Sales       Yes
# 4  30.0       NaN           5    Male         HR        No
# 5  45.0   90000.0          10  Female         IT       Yes
# 6  50.0  120000.0          15    Male      Sales        No
# 7  22.0   30000.0           2  Female         IT        No

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         7 non-null      float64
#  1   Salary      7 non-null      float64
#  2   Experience  8 non-null      int64
#  3   Gender      8 non-null      str
#  4   Department  8 non-null      str
#  5   Purchased   8 non-null      str
# dtypes: float64(2), int64(1), str(3)
# memory usage: 516.0 bytes

# %%
df.describe()
# Out:
#              Age         Salary  Experience
# count   7.000000       7.000000    8.000000
# mean   30.285714   55000.000000    5.250000
# std    12.392394   36628.768293    4.832923
# min    18.000000   20000.000000    1.000000
# 25%    22.000000   30000.000000    2.000000
# 50%    25.000000   45000.000000    3.500000
# 75%    37.500000   70000.000000    6.250000
# max    50.000000  120000.000000   15.000000

# %%
df.shape
# Out:
# (8, 6)

# %%
df.columns
# Out:
# Index(['Age', 'Salary', 'Experience', 'Gender', 'Department', 'Purchased'], dtype='str')

# %%
df.dtypes
# Out:
# Age           float64
# Salary        float64
# Experience      int64
# Gender            str
# Department        str
# Purchased         str
# dtype: object

# %%
df.isnull()
# Out:
#      Age  Salary  Experience  Gender  Department  Purchased
# 0  False   False       False   False       False      False
# 1  False   False       False   False       False      False
# 2  False   False       False   False       False      False
# 3   True   False       False   False       False      False
# 4  False    True       False   False       False      False
# 5  False   False       False   False       False      False
# 6  False   False       False   False       False      False
# 7  False   False       False   False       False      False

# %%
df.isnull().sum()
# Out:
# Age           1
# Salary        1
# Experience    0
# Gender        0
# Department    0
# Purchased     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].median())

# %%
df.shape
# Out:
# (8, 6)

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7, 6)

# %%
df
# Out:
#          Age    Salary  Experience  Gender Department Purchased
# 0  18.000000   20000.0           1    Male         HR       Yes
# 1  22.000000   30000.0           2  Female         IT        No
# 2  25.000000   45000.0           3  Female         IT       Yes
# 3  30.285714   50000.0           4    Male      Sales       Yes
# 4  30.000000   45000.0           5    Male         HR        No
# 5  45.000000   90000.0          10  Female         IT       Yes
# 6  50.000000  120000.0          15    Male      Sales        No

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      4
# Female    3
# Name: count, dtype: int64

# %%
df['Department'].unique()
# Out:
# <StringArray>
# ['HR', 'IT', 'Sales']
# Length: 3, dtype: str

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# Yes    4
# No     3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(df['Age'])
# Out:
# (array([1., 1., 1., 2., 0., 0., 0., 0., 1., 1.]),
#  array([18. , 21.2, 24.4, 27.6, 30.8, 34. , 37.2, 40.4, 43.6, 46.8, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Salary'])
# Out:
# (array([1., 1., 2., 1., 0., 0., 0., 1., 0., 1.]),
#  array([ 20000.,  30000.,  40000.,  50000.,  60000.,  70000.,  80000.,
#          90000., 100000., 110000., 120000.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['Age'],y=df['Salary'])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.countplot(x=df["Gender"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(y=df["Salary"])
# Out:
# <Axes: ylabel='Salary'>

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)
IQR = Q3 - Q1

# %%
sns.boxplot(y=IQR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.boxplot(y=IQR)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  Age    Salary  Experience
# Age         1.000000  0.983415    0.977851
# Salary      0.983415  1.000000    0.989762
# Experience  0.977851  0.989762    1.000000

# %%
sns.boxplot(y=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

df = df[(df["Salary"] >= lower) & (df["Salary"] <= upper)]

# %%
Salary = [20000,25000,30000,35000,40000,900000]

# %%
data = {
    "Salary":[20000,25000,30000,35000,40000,900000]
}
d=pd.DataFrame(data)
d
# Out:
#    Salary
# 0   20000
# 1   25000
# 2   30000
# 3   35000
# 4   40000
# 5  900000

# %%
import pandas as pd

# %%
data = {
    "Salary":[20000,30000,45000,50000,90000,1000000,30000]
}
d=pd.DataFrame(data)
d
# Out:
#     Salary
# 0    20000
# 1    30000
# 2    45000
# 3    50000
# 4    90000
# 5  1000000
# 6    30000

# %%
q1=d['Salary'].quantile(0.25)
q1
# Out:
# np.float64(30000.0)

# %%
q3=d['Salary'].quantile(0.75)
q3
# Out:
# np.float64(70000.0)

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(40000.0)

# %%
L=q1-1.5*IQR
L
# Out:
# np.float64(-30000.0)

# %%
U=q3+1.5*IQR
U
# Out:
# np.float64(130000.0)

# %%
d=d[(d['Salary' ] < L) | (d['Salary'] > U)]
d
# Out:
#     Salary
# 5  1000000

# %%
d = d[(d["Salary"] >= L) & (d["Salary"] <= U)]
d
# Out:
# Empty DataFrame
# Columns: [Salary]
# Index: []

# %%
df['Salary']
# Out:
# 0     20000.0
# 1     30000.0
# 2     45000.0
# 3     50000.0
# 5     90000.0
# 6    120000.0
# 7     30000.0
# Name: Salary, dtype: float64

# %%
print(d)
# Out:
# Empty DataFrame
# Columns: [Salary]
# Index: []

# %%
d
# Out:
# Empty DataFrame
# Columns: [Salary]
# Index: []

# %%
d.shape
# Out:
# (0, 1)

# %%
print("Before Removing")
print(df)

print(df.shape)

# Remove outlier
df = df[(df["Salary"] >= L) & (df["Salary"] <= U)]

print("After Removing")
print(df)

print(df.shape)

# Check remaining outliers
outlier = df[(df["Salary"] < L) | (df["Salary"] > U)]
print(outlier)
# Out:
# Before Removing
#     Age    Salary  Experience  Gender Department Purchased
# 0  18.0   20000.0           1    Male         HR       Yes
# 1  22.0   30000.0           2  Female         IT        No
# 2  25.0   45000.0           3  Female         IT       Yes
# 3   NaN   50000.0           4    Male      Sales       Yes
# 5  45.0   90000.0          10  Female         IT       Yes
# 6  50.0  120000.0          15    Male      Sales        No
# 7  22.0   30000.0           2  Female         IT        No
# (7, 6)
# After Removing
#     Age    Salary  Experience  Gender Department Purchased
# 0  18.0   20000.0           1    Male         HR       Yes
# 1  22.0   30000.0           2  Female         IT        No
# 2  25.0   45000.0           3  Female         IT       Yes
# 3   NaN   50000.0           4    Male      Sales       Yes
# 5  45.0   90000.0          10  Female         IT       Yes
# 6  50.0  120000.0          15    Male      Sales        No
# ...

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Q1 =", Q1)
print("Q3 =", Q3)
print("IQR =", IQR)
print("Lower =", lower)
print("Upper =", upper)
print("Max Salary =", df["Salary"].max())
# Out:
# Q1 = 30000.0
# Q3 = 70000.0
# IQR = 40000.0
# Lower = -30000.0
# Upper = 130000.0
# Max Salary = 120000.0

# %%
df
# Out:
#     Age    Salary  Experience  Gender Department Purchased
# 0  18.0   20000.0           1    Male         HR       Yes
# 1  22.0   30000.0           2  Female         IT        No
# 2  25.0   45000.0           3  Female         IT       Yes
# 3   NaN   50000.0           4    Male      Sales       Yes
# 4  30.0       NaN           5    Male         HR        No
# 5  45.0   90000.0          10  Female         IT       Yes
# 6  50.0  120000.0          15    Male      Sales        No
# 7  22.0   30000.0           2  Female         IT        No

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
from scipy import stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from scipy import stats
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Histogram
sns.histplot(df["Salary"], kde=True)
plt.show()

# Boxplot
sns.boxplot(y=df["Salary"])
plt.show()

# Skewness
print(df["Salary"].skew())

# Q-Q Plot
stats.probplot(df["Salary"], dist="norm", plot=plt)
plt.show()
# Out:
# 1.150200695953821
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 13
#       9 # Skewness
#      10 print(df["Salary"].skew())
#      11
#      12 # Q-Q Plot
# ---> 13 from scipy import stats
#      14 stats.probplot(df["Salary"], dist="norm", plot=plt)
#      15 plt.show()
#
# ModuleNotFoundError: No module named 'scipy'

# %%
from scipy import stats
import matplotlib.pyplot as plt

stats.probplot(df["Salary"], dist="norm", plot=plt)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from scipy import stats
#       2 import matplotlib.pyplot as plt
#       3
#       4 stats.probplot(df["Salary"], dist="norm", plot=plt)
#
# ModuleNotFoundError: No module named 'scipy'
