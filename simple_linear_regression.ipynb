# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("CGPA_Package_Dataset.csv")

# %%
df.head()
# Out:
#    CGPA  Package_LPA
# 0   5.5          3.2
# 1   6.0          3.5
# 2   6.3          3.8
# 3   6.8          4.2
# 4   7.0          4.8

# %%
df.isnull().sum()
# Out:
# CGPA           0
# Package_LPA    0
# dtype: int64

# %%
x=df[["CGPA"]]
y=df["Package_LPA"]

# %%
sns.scatterplot(x="CGPA"   ,y="Package_LPA", data=df)
# Out:
# <Axes: xlabel='CGPA', ylabel='Package_LPA'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict([[6.0]])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [raw]
# lr.score(x_test,y_test)

# %%
# y=m*x+c

# %%
lr.coef_  
# m value
# Out:
# array([2.3589684])

# %%
lr.intercept_
# c value
# Out:
# np.float64(-11.651022304832708)

# %%
# y=2.3589684*x+(-11.651022304832708)

# %%
y=2.3589684*6.0+(-11.651022304832708)

# %%
y
# Out:
# 2.5027880951672934
